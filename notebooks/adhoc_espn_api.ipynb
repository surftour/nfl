# %%
import requests
import json
import pandas as pd
from datetime import datetime

# %%
import sys
print(sys.version)
# Out:
# 3.12.8 (main, Jul  3 2025, 14:08:45) [Clang 16.0.0 (clang-1600.0.26.3)]

# %% [markdown]
# ## Info
#
# Some random assortment of ESPN APIs:<br>
# https://zudoku.dev/demo/~endpoints?api-url=https://raw.githubusercontent.com/zuplo/espn-openapi/refs/heads/main/espn_openapi_soccer_league_path.yaml#get-latest-nfl-scores
#
# decently long description of NFL API Endpoints<br>
# https://gist.github.com/nntrn/ee26cb2a0716de0947a0a4e9a157bc1c
#
# a few items listed, and some comments<br>
# https://gist.github.com/akeaswaran/b48b02f1c94f873c6655e7129910fc3b

# %%
def quickcheck(url):
    print(url)
    headers = {"accept": "application/json"}
    response = requests.get(url, headers=headers)
    print("response.status_code = " + str(response.status_code))
    return response

# %% [markdown]
# ## various endpoints

# %%
#
# next week's schedule (in this case week 1 of 2025 season) in lots of detail
#
# quickcheck("https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard").json()
quickcheck("https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard?year=2024&week=4").json()
# Out:
# https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard?year=2024&week=4
# response.status_code = 200
# {'leagues': [{'id': '28',
#    'uid': 's:20~l:28',
#    'name': 'National Football League',
#    'abbreviation': 'NFL',
#    'slug': 'nfl',
#    'season': {'year': 2025,
#     'startDate': '2025-07-31T07:00Z',
#     'endDate': '2026-02-12T07:59Z',
#     'displayName': '2025',
#     'type': {'id': '1',
#      'type': 1,
#      'name': 'Preseason',
#      'abbreviation': 'pre'}},
#    'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/leagues/500/nfl.png',
#      'width': 500,
#      'height': 500,
#      'alt': '',
#      'rel': ['full', 'default'],
#      'lastUpdated': '2018-06-05T12:07Z'},
#     {'href': 'https://a.espncdn.com/i/teamlogos/leagues/500-dark/nfl.png',
#      'width': 500,
#      'height': 500,
#      'alt': '',
#      'rel': ['full', 'dark'],
#      'lastUpdated': '2024-07-22T16:53Z'}],
#    'calendarType': 'list',
#    'calendarIsWhitelist': True,
# ...

# %%
# 
# a long list of teams, and their detailed info
# 
quickcheck("http://site.api.espn.com/apis/site/v2/sports/football/nfl/teams").json()
# Out:
# http://site.api.espn.com/apis/site/v2/sports/football/nfl/teams
# response.status_code = 200
# {'sports': [{'id': '20',
#    'uid': 's:20',
#    'name': 'Football',
#    'slug': 'football',
#    'leagues': [{'id': '28',
#      'uid': 's:20~l:28',
#      'name': 'National Football League',
#      'abbreviation': 'NFL',
#      'shortName': 'NFL',
#      'slug': 'nfl',
#      'teams': [{'team': {'id': '22',
#         'uid': 's:20~l:28~t:22',
#         'slug': 'arizona-cardinals',
#         'abbreviation': 'ARI',
#         'displayName': 'Arizona Cardinals',
#         'shortDisplayName': 'Cardinals',
#         'name': 'Cardinals',
#         'nickname': 'Cardinals',
#         'location': 'Arizona',
#         'color': 'a40227',
#         'alternateColor': 'ffffff',
#         'isActive': True,
#         'isAllStar': False,
#         'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/nfl/500/ari.png',
#           'alt': '',
#           'rel': ['full', 'default'],
# ...

# %%
# 
# a list of links to all nfl teams
# 
quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/teams").json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/teams
# response.status_code = 200
# {'count': 32,
#  'pageIndex': 1,
#  'pageSize': 25,
#  'pageCount': 2,
#  'items': [{'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2025/teams/22?lang=en&region=us'},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2025/teams/1?lang=en&region=us'},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2025/teams/33?lang=en&region=us'},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2025/teams/2?lang=en&region=us'},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2025/teams/29?lang=en&region=us'},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2025/teams/3?lang=en&region=us'},
# ...

# %%
# 
# a detailed team info
# 
# API = "http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/1" # atlanta falcons
# API = "http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/9" # GB
# API = "http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/19" # New York Giants
# API = "http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/22" # arizona cardinals
API = "http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2025/teams/25?lang=en&region=us" # sf niners
quickcheck(API).json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2025/teams/25?lang=en&region=us
# response.status_code = 200
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2025/teams/25?lang=en&region=us',
#  'id': '25',
#  'guid': '985a261f-296c-c95c-32a5-addc4df75001',
#  'uid': 's:20~l:28~t:25',
#  'alternateIds': {'sdr': '8826'},
#  'slug': 'san-francisco-49ers',
#  'location': 'San Francisco',
#  'name': '49ers',
#  'nickname': '49ers',
#  'abbreviation': 'SF',
#  'displayName': 'San Francisco 49ers',
#  'shortDisplayName': '49ers',
#  'color': 'aa0000',
#  'alternateColor': 'b3995d',
#  'isActive': True,
#  'isAllStar': False,
#  'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/nfl/500/sf.png',
#    'width': 500,
#    'height': 500,
#    'alt': '',
#    'rel': ['full', 'default'],
#    'lastUpdated': '2024-06-25T18:56Z'},
#   {'href': 'https://a.espncdn.com/i/teamlogos/nfl/500-dark/sf.png',
#    'width': 500,
#    'height': 500,
# ...

# %%
# 
# some of the links from the above team pages
# 
# # team leaders, like the per-person lists by topic
# API = "http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/leaders?limit=10"
#
# pure list of links to events
# API = "http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2025/teams/9/events?lang=en&region=us"
# 
# nothing at the current moment, no matter the year/team
API = "http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/25/ranks" # ?lang=en&region=us"

quickcheck(API).json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/25/ranks
# response.status_code = 200
# {'count': 0, 'pageIndex': 0, 'pageSize': 25, 'pageCount': 0, 'items': []}

# %%
quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/weeks/17?lang=en&region=us").json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/weeks/17?lang=en&region=us
# response.status_code = 200
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/weeks/17?lang=en&region=us',
#  'number': 17,
#  'startDate': '2021-12-29T08:00Z',
#  'endDate': '2022-01-05T07:59Z',
#  'text': 'Week 17',
#  'rankings': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/weeks/17/rankings?lang=en&region=us'},
#  'events': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/weeks/17/events?lang=en&region=us'},
#  'talentpicks': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/weeks/17/talentpicks?lang=en&region=us'},
#  'qbr': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/weeks/17/qbr/10000?lang=en&region=us'}}

# %%
quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/15/rankings?lang=en&region=us").json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/15/rankings?lang=en&region=us
# response.status_code = 200
# {'count': 0, 'pageIndex': 0, 'pageSize': 25, 'pageCount': 0, 'items': []}

# %%
quickcheck("https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/groups/1/standings").json()
# Out:
# https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/groups/1/standings
# response.status_code = 200
# {'count': 4,
#  'pageIndex': 1,
#  'pageSize': 25,
#  'pageCount': 1,
#  'items': [{'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/groups/1/standings/0?lang=en&region=us',
#    'id': '0',
#    'name': 'overall',
#    'displayName': 'Standings',
#    'links': [{'language': 'en-US',
#      'rel': ['standings', 'desktop'],
#      'href': 'https://www.espn.com/nfl/standings/_/group/1',
#      'text': 'Table',
#      'shortText': 'Standings',
#      'isExternal': False,
#      'isPremium': False}]},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/groups/1/standings/1?lang=en&region=us',
#    'id': '1',
#    'name': 'playoff',
#    'displayName': 'Playoff Standings',
#    'links': [{'language': 'en-US',
#      'rel': ['standings', 'desktop'],
# ...

# %%
#
# somewhat interesting, seems like it's a per-team summary of where they rank in a bunch of
# random categories.  you could probably wrangle this into a league-wide ranking in various
# categories
#
quickcheck("https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/teams/25/statistics").json()
# Out:
# https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/teams/25/statistics
# response.status_code = 200
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/teams/25/statistics/0?lang=en&region=us',
#  'season': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024?lang=en&region=us'},
#  'team': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/25?lang=en&region=us'},
#  'splits': {'id': '0',
#   'name': 'All Splits',
#   'abbreviation': 'Any',
#   'categories': [{'name': 'general',
#     'displayName': 'General',
#     'shortDisplayName': 'General',
#     'abbreviation': 'gen',
#     'summary': '',
#     'stats': [{'name': 'fumbles',
#       'displayName': 'Fumbles',
#       'shortDisplayName': 'F',
#       'description': 'The number of times a player/team has fumbled the ball',
#       'abbreviation': 'FUM',
#       'value': 26.0,
# ...

# %%
#quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/4/groups/7?lang=en&region=us").json()
#quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/4/groups/8?lang=en&region=us").json()
#quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/4/groups/6?lang=en&region=us").json()
quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/4/groups/9?lang=en&region=us").json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/4/groups/9?lang=en&region=us
# response.status_code = 200
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/4/groups/9?lang=en&region=us',
#  'uid': 's:20~l:28~g:9',
#  'id': '9',
#  'name': 'National Football League',
#  'abbreviation': 'NFL',
#  'shortName': 'NFL',
#  'season': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021?lang=en&region=us'},
#  'children': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/4/groups/9/children?lang=en&region=us'},
#  'standings': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/4/groups/9/standings?lang=en&region=us'},
#  'isConference': False,
#  'slug': 'national-football-league',
# ...

# %%
quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024?lang=en&region=us").json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024?lang=en&region=us
# response.status_code = 200
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024?lang=en&region=us',
#  'year': 2024,
#  'startDate': '2024-08-01T07:00Z',
#  'endDate': '2025-01-22T07:59Z',
#  'displayName': '2024',
#  'type': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2?lang=en&region=us',
#   'id': '2',
#   'type': 2,
#   'name': 'Regular Season',
#   'abbreviation': 'reg',
#   'year': 2024,
#   'startDate': '2024-09-05T07:00Z',
#   'endDate': '2025-01-09T07:59Z',
#   'hasGroups': False,
#   'hasStandings': True,
#   'hasLegs': False,
#   'groups': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/groups?lang=en&region=us'},
#   'weeks': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks?lang=en&region=us'},
# ...

# %%
quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/13?lang=en&region=us").json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/13?lang=en&region=us
# response.status_code = 200
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/13?lang=en&region=us',
#  'number': 13,
#  'startDate': '2024-11-27T08:00Z',
#  'endDate': '2024-12-04T07:59Z',
#  'text': 'Week 13',
#  'rankings': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/13/rankings?lang=en&region=us'},
#  'events': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/13/events?lang=en&region=us'},
#  'talentpicks': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/13/talentpicks?lang=en&region=us'},
#  'qbr': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/13/qbr/10000?lang=en&region=us'}}

# %%
quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/13/rankings?lang=en&region=us").json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/13/rankings?lang=en&region=us
# response.status_code = 200
# {'count': 0, 'pageIndex': 0, 'pageSize': 25, 'pageCount': 0, 'items': []}

# %%
quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/groups?lang=en&region=us").json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/groups?lang=en&region=us
# response.status_code = 200
# {'count': 2,
#  'pageIndex': 1,
#  'pageSize': 25,
#  'pageCount': 1,
#  'items': [{'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/groups/8?lang=en&region=us'},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2021/types/2/groups/7?lang=en&region=us'}]}

# %%
quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/12/").json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/12/
# response.status_code = 200
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/12?lang=en&region=us',
#  'number': 12,
#  'startDate': '2024-11-20T08:00Z',
#  'endDate': '2024-11-27T07:59Z',
#  'text': 'Week 12',
#  'teamsOnBye': [{'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/1?lang=en&region=us'},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/2?lang=en&region=us'},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/4?lang=en&region=us'},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/18?lang=en&region=us'},
#   {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/20?lang=en&region=us'},
# ...

# %%
quickcheck("http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/12/rankings/off").json()
# Out:
# http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/weeks/12/rankings/off
# response.status_code = 404
# {'error': {'message': 'application error', 'code': 404}}

# %%
quickcheck("https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/stats").json()
# Out:
# https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/stats
# response.status_code = 404
# {'error': {'message': 'application error', 'code': 404}}

# %% [markdown]
# ## Parse stats call into Dataframe

# %%
teamrankings = quickcheck("https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/teams/25/statistics")
# Out:
# https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/teams/25/statistics
# response.status_code = 200

# %%
teamrankings?
# Out:
# Type:        Response
# String form: <Response [200]>
# File:        ~/.pyenv/versions/nfl-testing/lib/python3.12/site-packages/requests/models.py
# Docstring:
# The :class:`Response <Response>` object, which contains a
# server's response to an HTTP request.

# %% [markdown]
# ### ad-hoc manipulation of team rankings

# %%
teamrankings.json()
# Out:
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/2/teams/25/statistics/0?lang=en&region=us',
#  'season': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024?lang=en&region=us'},
#  'team': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/teams/25?lang=en&region=us'},
#  'splits': {'id': '0',
#   'name': 'All Splits',
#   'abbreviation': 'Any',
#   'categories': [{'name': 'general',
#     'displayName': 'General',
#     'shortDisplayName': 'General',
#     'abbreviation': 'gen',
#     'summary': '',
#     'stats': [{'name': 'fumbles',
#       'displayName': 'Fumbles',
#       'shortDisplayName': 'F',
#       'description': 'The number of times a player/team has fumbled the ball',
#       'abbreviation': 'FUM',
#       'value': 26.0,
#       'displayValue': '26',
#       'perGameValue': 1.0,
#       'perGameDisplayValue': '1',
#       'rank': 5,
# ...

# %%
type(teamrankings.json())
# Out:
# dict

# %%
type(teamrankings.json()["splits"]["categories"])
# Out:
# list

# %%
len(teamrankings.json()["splits"]["categories"])
# Out:
# 11

# %%
teamrankings.json()["splits"]["categories"]
# Out:
# [{'name': 'general',
#   'displayName': 'General',
#   'shortDisplayName': 'General',
#   'abbreviation': 'gen',
#   'summary': '',
#   'stats': [{'name': 'fumbles',
#     'displayName': 'Fumbles',
#     'shortDisplayName': 'F',
#     'description': 'The number of times a player/team has fumbled the ball',
#     'abbreviation': 'FUM',
#     'value': 26.0,
#     'displayValue': '26',
#     'perGameValue': 1.0,
#     'perGameDisplayValue': '1',
#     'rank': 5,
#     'rankDisplayValue': 'Tied-5th'},
#    {'name': 'fumblesLost',
#     'displayName': 'Fumbles Lost',
#     'shortDisplayName': 'FL',
#     'description': 'The number of times a fumble is recovered by the opposing team',
#     'abbreviation': 'LST',
#     'value': 11.0,
#     'displayValue': '11',
#     'rank': 6,
#     'rankDisplayValue': 'Tied-6th'},
#    {'name': 'fumblesForced',
#     'displayName': 'Forced Fumbles',
#     'shortDisplayName': 'Forced Fumbles',
#     'description': 'The total number of forced fumbles.',
# ...

# %%
for cat in teamrankings.json()["splits"]["categories"]:
    print(cat["name"], cat["displayName"])
# Out:
# general General
# passing Passing
# rushing Rushing
# receiving Receiving
# defensive Defense
# defensiveInterceptions Defensive Interceptions
# kicking Kicking
# returning Returning
# punting Punting
# scoring Scoring
# miscellaneous Miscellaneous

# %%
type(teamrankings.json()["splits"]["categories"][0]["stats"])
# Out:
# list

# %%
for cat in teamrankings.json()["splits"]["categories"][1]["stats"]:
    print(cat["name"], cat["displayName"])
# Out:
# avgGain Average Gain
# completionPct Completion Percentage
# completions Completions
# ESPNQBRating ESPN Quarterback Rating
# interceptionPct Interception Percentage
# interceptions Interceptions
# longPassing Longest Pass
# miscYards Miscellaneous Yards
# netPassingYards Net Passing Yards
# netPassingYardsPerGame Net Passing Yards Per Game
# netTotalYards Net Total Yards
# netYardsPerGame Net Yards Per Game
# passingAttempts Passing Attempts
# passingBigPlays Passing Big Plays
# passingFirstDowns Passing 1st downs
# passingFumbles Passing Fumbles
# passingFumblesLost Passing Fumbles Lost
# passingTouchdownPct Passing Touchdown %
# passingTouchdowns Passing Touchdowns
# passingYards Passing Yards
# passingYardsAfterCatch Passing Yards After Catch
# passingYardsAtCatch Passing Yards At Catch
# passingYardsPerGame Passing Yards Per Game
# QBRating Passer Rating
# sacks Total Sacks
# sackYardsLost Sack Yards Lost
# netPassingAttempts Net Passing Attempts
# ...

# %%
teamrankings.json()["splits"]["categories"][0]
# Out:
# {'name': 'general',
#  'displayName': 'General',
#  'shortDisplayName': 'General',
#  'abbreviation': 'gen',
#  'summary': '',
#  'stats': [{'name': 'fumbles',
#    'displayName': 'Fumbles',
#    'shortDisplayName': 'F',
#    'description': 'The number of times a player/team has fumbled the ball',
#    'abbreviation': 'FUM',
#    'value': 26.0,
#    'displayValue': '26',
#    'perGameValue': 1.0,
#    'perGameDisplayValue': '1',
#    'rank': 5,
#    'rankDisplayValue': 'Tied-5th'},
#   {'name': 'fumblesLost',
#    'displayName': 'Fumbles Lost',
#    'shortDisplayName': 'FL',
#    'description': 'The number of times a fumble is recovered by the opposing team',
#    'abbreviation': 'LST',
#    'value': 11.0,
#    'displayValue': '11',
#    'rank': 6,
#    'rankDisplayValue': 'Tied-6th'},
#   {'name': 'fumblesForced',
#    'displayName': 'Forced Fumbles',
#    'shortDisplayName': 'Forced Fumbles',
#    'description': 'The total number of forced fumbles.',
#    'abbreviation': 'FF',
# ...

# %% [markdown]
# ### dump to json

# %%
with open("nfl_teamteamrankings_2024.json", "w") as fp:
    json.dump(teamrankings.json(), fp)

# %%
teamrankings_SF_2023 = quickcheck("https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2023/types/2/teams/25/statistics")

with open("nfl_teamteamrankings_SF_2023.json", "w") as fp:
    json.dump(teamrankings_SF_2023.json(), fp)
# Out:
# https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2023/types/2/teams/25/statistics
# response.status_code = 200

# %% [markdown]
# ### test modules

# %%
sys.path.append('../')

# %%
import src.api.espn as espn

# %%
df = espn.fetch_team_stats(2024, 22)

# %%
df.head()
# Out:
#   category               name         displayName shortDisplayName  \
# 0  general            fumbles             Fumbles                F
# 1  general        fumblesLost        Fumbles Lost               FL
# 2  general      fumblesForced      Forced Fumbles   Forced Fumbles
# 3  general   fumblesRecovered   Fumbles Recovered               FR
# 4  general  fumblesTouchdowns  Fumbles Touchdowns              FTD
#
#                                          description  value displayValue
# 0  The number of times a player/team has fumbled ...   21.0           21
# 1  The number of times a fumble is recovered by t...    9.0            9
# 2                The total number of forced fumbles.   17.0           17
# 3                   The number of fumbles recovered.    8.0            8
# 4  The number of times a fumbles is recovered and...    2.0            2

# %%
nflteams = espn.fetch_teams()

# %%
nflteams.head()
# Out:
#    id             uid               slug abbreviation        displayName  \
# 0  22  s:20~l:28~t:22  arizona-cardinals          ARI  Arizona Cardinals
# 1   1   s:20~l:28~t:1    atlanta-falcons          ATL    Atlanta Falcons
# 2  33  s:20~l:28~t:33   baltimore-ravens          BAL   Baltimore Ravens
# 3   2   s:20~l:28~t:2      buffalo-bills          BUF      Buffalo Bills
# 4  29  s:20~l:28~t:29  carolina-panthers          CAR  Carolina Panthers
#
#   shortDisplayName       name   nickname   location   color alternateColor  \
# 0        Cardinals  Cardinals  Cardinals    Arizona  a40227         ffffff
# 1          Falcons    Falcons    Falcons    Atlanta  a71930         000000
# 2           Ravens     Ravens     Ravens  Baltimore  29126f         000000
# 3            Bills      Bills      Bills    Buffalo  00338d         d50a0a
# 4         Panthers   Panthers   Panthers   Carolina  0085ca         000000
#
#    isActive  isAllStar                                           logo_url
# ...

# %%
# nflteams.info
nflteams.dtypes
# nflteams.printSchema()
# Out:
# id                  object
# uid                 object
# slug                object
# abbreviation        object
# displayName         object
# shortDisplayName    object
# name                object
# nickname            object
# location            object
# color               object
# alternateColor      object
# isActive              bool
# isAllStar             bool
# logo_url            object
# dtype: object

# %%
# nflteams.query("id = '22'").show()
nflteams.loc[nflteams['id'] == '25'].head()
# Out:
#     id             uid                 slug abbreviation          displayName  \
# 27  25  s:20~l:28~t:25  san-francisco-49ers           SF  San Francisco 49ers
#
#    shortDisplayName   name nickname       location   color alternateColor  \
# 27            49ers  49ers    49ers  San Francisco  aa0000         b3995d
#
#     isActive  isAllStar                                          logo_url
# 27      True      False  https://a.espncdn.com/i/teamlogos/nfl/500/sf.png

# %%
nflteams[nflteams['id'] == '25'].head()
# Out:
#     id             uid                 slug abbreviation          displayName  \
# 27  25  s:20~l:28~t:25  san-francisco-49ers           SF  San Francisco 49ers
#
#    shortDisplayName   name nickname       location   color alternateColor  \
# 27            49ers  49ers    49ers  San Francisco  aa0000         b3995d
#
#     isActive  isAllStar                                          logo_url
# 27      True      False  https://a.espncdn.com/i/teamlogos/nfl/500/sf.png

# %%
games = espn.fetch_game_results(2024)
# games = espn.fetch_game_results(2023)

# %%
games.head()
# Out:
#           id                    uid               date  \
# 0  401772510  s:20~l:28~e:401772510  2025-09-05T00:20Z
# 1  401772714  s:20~l:28~e:401772714  2025-09-06T00:00Z
# 2  401772830  s:20~l:28~e:401772830  2025-09-07T17:00Z
# 3  401772829  s:20~l:28~e:401772829  2025-09-07T17:00Z
# 4  401772719  s:20~l:28~e:401772719  2025-09-07T17:00Z
#
#                                          name  shortName  season  week  \
# 0       Dallas Cowboys at Philadelphia Eagles  DAL @ PHI    2025     1
# 1  Kansas City Chiefs at Los Angeles Chargers  KC VS LAC    2025     1
# 2     Tampa Bay Buccaneers at Atlanta Falcons   TB @ ATL    2025     1
# 3      Cincinnati Bengals at Cleveland Browns  CIN @ CLE    2025     1
# 4        Miami Dolphins at Indianapolis Colts  MIA @ IND    2025     1
#
#    season_type            status  completed  ... home_team_score  \
# 0            2  STATUS_SCHEDULED      False  ...               0
# 1            2  STATUS_SCHEDULED      False  ...               0
# ...

# %%
games.head()
# Out:
#           id                    uid               date  \
# 0  401772510  s:20~l:28~e:401772510  2025-09-05T00:20Z
# 1  401772714  s:20~l:28~e:401772714  2025-09-06T00:00Z
# 2  401772830  s:20~l:28~e:401772830  2025-09-07T17:00Z
# 3  401772829  s:20~l:28~e:401772829  2025-09-07T17:00Z
# 4  401772719  s:20~l:28~e:401772719  2025-09-07T17:00Z
#
#                                          name  shortName  season  week  \
# 0       Dallas Cowboys at Philadelphia Eagles  DAL @ PHI    2025     1
# 1  Kansas City Chiefs at Los Angeles Chargers  KC VS LAC    2025     1
# 2     Tampa Bay Buccaneers at Atlanta Falcons   TB @ ATL    2025     1
# 3      Cincinnati Bengals at Cleveland Browns  CIN @ CLE    2025     1
# 4        Miami Dolphins at Indianapolis Colts  MIA @ IND    2025     1
#
#    season_type            status  completed  ... home_team_score  \
# 0            2  STATUS_SCHEDULED      False  ...               0
# 1            2  STATUS_SCHEDULED      False  ...               0
# ...

# %%
games.groupby("week").count().head(20)
# Out:
#       id  uid  date  name  shortName  season  season_type  status  completed  \
# week
# 1     16   16    16    16         16      16           16      16         16
#
#       home_team_id  ...  home_team_score  home_team_winner  away_team_id  \
# week                ...
# 1               16  ...               16                16            16
#
#       away_team_name  away_team_abbr  away_team_score  away_team_winner  \
# week
# 1                 16              16               16                16
#
#       venue_name  venue_city  venue_state
# week
# 1             16          16           16
#
# [1 rows x 22 columns]

# %% [markdown]
# ### blank
