# %%
import requests
import json
import pandas as pd
from datetime import datetime
import sys
print(sys.version)
# Out:
# 3.12.8 (main, Jul  3 2025, 14:08:45) [Clang 16.0.0 (clang-1600.0.26.3)]

# %%
sys.path.append('../')
import src.api.espn as espn
import src.data.reader_weekly_offdef as weekly_reader
import src.data.reader_weekly_results as weekly_results_reader
import src.analytics.game_team_stats as game_team_stats

# %%
weekly_results_reader.read_results?
# Out:
# Signature: weekly_results_reader.read_results(year: int, week: int)
# Docstring:
# Read weekly game results for a specific year and week.
#
# Args:
#     year (int): Four digit year (e.g., 2024)
#     week (int): Week number (e.g., 1, 15)
#
# Returns:
#     DataFrame with columns: date, result_visiting_team, result_visiting_score, result_home_team, result_home_score, result_status, year, week
# File:      ~/nfl/src/data/reader_weekly_results.py
# Type:      function

# %%
# weekly_results_reader.read_results("/Users/tj/nfl/data/2022/week4/results.tsv")
weekly_results_reader.read_results(2022, 4)
# Out:
#             date   result_visiting_team  result_visiting_score  \
# 0   Sep 29, 2022         Miami Dolphins                     15
# 1    Oct 2, 2022      Minnesota Vikings                     28
# 2    Oct 2, 2022       Cleveland Browns                     20
# 3    Oct 2, 2022       Tennessee Titans                     24
# 4    Oct 2, 2022  Washington Commanders                     10
# 5    Oct 2, 2022       Seattle Seahawks                     48
# 6    Oct 2, 2022   Los Angeles Chargers                     34
# 7    Oct 2, 2022          Chicago Bears                     12
# 8    Oct 2, 2022   Jacksonville Jaguars                     21
# 9    Oct 2, 2022          New York Jets                     24
# 10   Oct 2, 2022          Buffalo Bills                     23
# 11   Oct 2, 2022      Arizona Cardinals                     26
# 12   Oct 2, 2022   New England Patriots                     24
# 13   Oct 2, 2022         Denver Broncos                     23
# 14   Oct 2, 2022     Kansas City Chiefs                     41
# 15   Oct 3, 2022       Los Angeles Rams                      9
#
#         result_home_team  result_home_score result_status  \
# 0     Cincinnati Bengals                 27         Final
# 1     New Orleans Saints                 25         Final
# 2        Atlanta Falcons                 23         Final
# 3     Indianapolis Colts                 17         Final
# 4         Dallas Cowboys                 25         Final
# 5          Detroit Lions                 45         Final
# 6         Houston Texans                 24         Final
# 7        New York Giants                 20         Final
# 8    Philadelphia Eagles                 29         Final
# 9    Pittsburgh Steelers                 20         Final
# 10      Baltimore Ravens                 20         Final
# 11     Carolina Panthers                 16         Final
# 12     Green Bay Packers                 27         Final
# 13     Las Vegas Raiders                 32         Final
# 14  Tampa Bay Buccaneers                 31         Final
# 15   San Francisco 49ers                 24         Final
#
#     result_visiting_win  result_home_win  result_total_points  \
# 0                     0                1                   42
# 1                     1                0                   53
# 2                     0                1                   43
# 3                     1                0                   41
# 4                     0                1                   35
# 5                     1                0                   93
# 6                     1                0                   58
# 7                     0                1                   32
# 8                     0                1                   50
# 9                     1                0                   44
# 10                    1                0                   43
# 11                    1                0                   42
# 12                    0                1                   51
# 13                    0                1                   55
# 14                    1                0                   72
# 15                    0                1                   33
#
#     result_point_differential  year  week
# 0                          12  2022     4
# 1                          -3  2022     4
# 2                           3  2022     4
# 3                          -7  2022     4
# 4                          15  2022     4
# 5                          -3  2022     4
# 6                         -10  2022     4
# 7                           8  2022     4
# 8                           8  2022     4
# 9                          -4  2022     4
# 10                         -3  2022     4
# 11                        -10  2022     4
# 12                          3  2022     4
# 13                          9  2022     4
# 14                        -10  2022     4
# 15                         15  2022     4

# %% [markdown]
# ### check combined

# %%
game_team_stats.combine_game_results_with_team_stats(2022,4)
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week04/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week04/def.csv
#             date   result_visiting_team  result_visiting_score  \
# 0   Sep 29, 2022         Miami Dolphins                     15
# 1    Oct 2, 2022      Minnesota Vikings                     28
# 2    Oct 2, 2022       Cleveland Browns                     20
# 3    Oct 2, 2022       Tennessee Titans                     24
# 4    Oct 2, 2022  Washington Commanders                     10
# 5    Oct 2, 2022       Seattle Seahawks                     48
# 6    Oct 2, 2022   Los Angeles Chargers                     34
# 7    Oct 2, 2022          Chicago Bears                     12
# 8    Oct 2, 2022   Jacksonville Jaguars                     21
# 9    Oct 2, 2022          New York Jets                     24
# 10   Oct 2, 2022          Buffalo Bills                     23
# 11   Oct 2, 2022      Arizona Cardinals                     26
# 12   Oct 2, 2022   New England Patriots                     24
# 13   Oct 2, 2022         Denver Broncos                     23
# 14   Oct 2, 2022     Kansas City Chiefs                     41
# 15   Oct 3, 2022       Los Angeles Rams                      9
#
#     result_visiting_win      result_home_team  result_home_score  \
# 0                     0    Cincinnati Bengals                 27
# 1                     1    New Orleans Saints                 25
# 2                     0       Atlanta Falcons                 23
# 3                     1    Indianapolis Colts                 17
# 4                     0        Dallas Cowboys                 25
# 5                     1         Detroit Lions                 45
# 6                     1        Houston Texans                 24
# 7                     0       New York Giants                 20
# 8                     0   Philadelphia Eagles                 29
# 9                     1   Pittsburgh Steelers                 20
# 10                    1      Baltimore Ravens                 20
# 11                    1     Carolina Panthers                 16
# 12                    0     Green Bay Packers                 27
# 13                    0     Las Vegas Raiders                 32
# 14                    1  Tampa Bay Buccaneers                 31
# 15                    0   San Francisco 49ers                 24
#
#     result_home_win  result_total_points  result_point_differential  \
# 0                 1                   42                         12
# 1                 0                   53                         -3
# 2                 1                   43                          3
# 3                 0                   41                         -7
# 4                 1                   35                         15
# 5                 0                   93                         -3
# 6                 0                   58                        -10
# 7                 1                   32                          8
# 8                 1                   50                          8
# 9                 0                   44                         -4
# 10                0                   43                         -3
# 11                0                   42                        -10
# 12                1                   51                          3
# 13                1                   55                          9
# 14                0                   72                        -10
# 15                1                   33                         15
#
#    result_status  ...  home_PassingTDPerGame_def  home_PassingIntPerGame_def  \
# 0          Final  ...                   0.666667                    0.666667
# 1          Final  ...                   0.666667                         0.0
# 2          Final  ...                   2.333333                         1.0
# 3          Final  ...                   1.666667                    0.333333
# 4          Final  ...                   0.666667                    0.666667
# 5          Final  ...                   1.666667                    0.333333
# 6          Final  ...                   0.666667                    1.333333
# 7          Final  ...                   1.333333                         0.0
# 8          Final  ...                        1.0                    1.333333
# 9          Final  ...                   1.666667                    1.666667
# 10         Final  ...                   2.333333                         2.0
# 11         Final  ...                        1.0                    0.666667
# 12         Final  ...                        1.0                    0.333333
# 13         Final  ...                   1.666667                    0.666667
# 14         Final  ...                        1.0                    1.666667
# 15         Final  ...                   0.666667                         1.0
#
#     home_Passing1stDPerGame_def  home_RushingAttPerGame_def  \
# 0                     10.666667                        23.0
# 1                           7.0                        33.0
# 2                     14.333333                   22.666667
# 3                     12.666667                   29.333333
# 4                          10.0                   27.666667
# 5                     14.333333                   28.333333
# 6                          12.0                   36.333333
# 7                     10.666667                   26.333333
# 8                          13.0                   20.333333
# 9                     14.666667                   34.333333
# 10                    17.333333                        21.0
# 11                     9.666667                   31.333333
# 12                     9.666667                        23.0
# 13                    12.666667                   28.666667
# 14                     9.333333                        21.0
# 15                     7.333333                        28.0
#
#     home_RushingYdsPerGame_def  home_RushingTDPerGame_def  \
# 0                         86.0                   0.333333
# 1                   139.333333                   0.666667
# 2                   109.333333                   0.666667
# 3                         77.0                   0.666667
# 4                        136.0                   0.333333
# 5                   142.333333                   2.333333
# 6                   202.333333                        1.0
# 7                   138.333333                   0.333333
# 8                        110.0                   1.333333
# 9                   142.666667                   0.666667
# 10                  104.666667                        1.0
# 11                  134.666667                   0.666667
# 12                  113.333333                   0.333333
# 13                  109.333333                   1.333333
# 14                   79.333333                        0.0
# 15                   78.666667                   0.666667
#
#     home_Rushing1stDPerGame_def  home_PenaltiesPenPerGame_def  \
# 0                           5.0                      5.666667
# 1                           7.0                      6.666667
# 2                      6.333333                      5.666667
# 3                      5.333333                           5.0
# 4                      7.333333                      6.666667
# 5                      9.333333                           5.0
# 6                      9.333333                      8.666667
# 7                           6.0                      6.666667
# 8                      5.666667                      5.333333
# 9                      7.666667                      5.333333
# 10                          6.0                      5.666667
# 11                     7.666667                           8.0
# 12                     5.666667                      5.333333
# 13                     7.333333                           8.0
# 14                     4.333333                           9.0
# 15                     4.666667                           6.0
#
#     home_PenaltiesYdsPerGame_def  home_Penalties1stPyPerGame_def
# 0                           53.0                        1.333333
# 1                      65.333333                             3.0
# 2                           69.0                             1.0
# 3                      34.666667                        2.333333
# 4                           39.0                        2.333333
# 5                           31.0                        2.333333
# 6                      73.666667                             2.0
# 7                      52.666667                        3.333333
# 8                           46.0                        2.333333
# 9                      35.333333                        1.666667
# 10                     49.333333                             1.0
# 11                     63.666667                        2.666667
# 12                     36.666667                             1.0
# 13                     75.333333                        1.666667
# 14                          66.0                             1.0
# 15                     53.333333                        2.333333
#
# [16 rows x 124 columns]

# %%
# both of these wrap the output, and also only show the first/last (replacing middle with " ... "
#
# print(game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv").dtypes)
# game_team_stats.combine_game_results_with_team_stats(2022,4).columns # wraps and only shows first/last

#
game_team_stats.combine_game_results_with_team_stats(2022,4).columns.tolist()
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week04/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week04/def.csv
# ['date',
#  'result_visiting_team',
#  'result_visiting_score',
#  'result_visiting_win',
#  'result_home_team',
#  'result_home_score',
#  'result_home_win',
#  'result_total_points',
#  'result_point_differential',
#  'result_status',
#  'year',
#  'week',
#  'visiting_Rk_off',
#  'visiting_G_off',
#  'visiting_TotYdsPlusTOYPerP_off',
#  'visiting_PassingNYPerA_off',
#  'visiting_RushingYPerA_off',
#  'visiting_Sc%_off',
#  'visiting_TO%_off',
#  'visiting_EXP_off',
#  'visiting_year_off',
#  'visiting_week_off',
#  'visiting_PFPerGame',
#  'visiting_YdsPerGame_off',
#  'visiting_TotYdsPlusTOPlyPerGame_off',
#  'visiting_TotYdsPlusTOTOPerGame_off',
#  'visiting_FLPerGame_off',
#  'visiting_1stDPerGame_off',
#  'visiting_PassingCmpPerGame_off',
#  'visiting_PassingAttPerGame_off',
#  'visiting_PassingYdsPerGame_off',
#  'visiting_PassingTDPerGame_off',
#  'visiting_PassingIntPerGame_off',
#  'visiting_Passing1stDPerGame_off',
#  'visiting_RushingAttPerGame_off',
#  'visiting_RushingYdsPerGame_off',
#  'visiting_RushingTDPerGame_off',
#  'visiting_Rushing1stDPerGame_off',
#  'visiting_PenaltiesPenPerGame_off',
#  'visiting_PenaltiesYdsPerGame_off',
#  'visiting_Penalties1stPyPerGame_off',
#  'visiting_Rk_def',
#  'visiting_G_def',
#  'visiting_PA',
#  'visiting_TotYdsPlusTOYPerP_def',
#  'visiting_PassingNYPerA_def',
#  'visiting_RushingYPerA_def',
#  'visiting_Sc%_def',
#  'visiting_TO%_def',
#  'visiting_EXP_def',
#  'visiting_YdsPerGame_def',
#  'visiting_TotYdsPlusTOPlyPerGame_def',
#  'visiting_TotYdsPlusTOTOPerGame_def',
#  'visiting_FLPerGame_def',
#  'visiting_1stDPerGame_def',
#  'visiting_PassingCmpPerGame_def',
#  'visiting_PassingAttPerGame_def',
#  'visiting_PassingYdsPerGame_def',
#  'visiting_PassingTDPerGame_def',
#  'visiting_PassingIntPerGame_def',
#  'visiting_Passing1stDPerGame_def',
#  'visiting_RushingAttPerGame_def',
#  'visiting_RushingYdsPerGame_def',
#  'visiting_RushingTDPerGame_def',
#  'visiting_Rushing1stDPerGame_def',
#  'visiting_PenaltiesPenPerGame_def',
#  'visiting_PenaltiesYdsPerGame_def',
#  'visiting_Penalties1stPyPerGame_def',
#  'home_Rk_off',
#  'home_G_off',
#  'home_TotYdsPlusTOYPerP_off',
#  'home_PassingNYPerA_off',
#  'home_RushingYPerA_off',
#  'home_Sc%_off',
#  'home_TO%_off',
#  'home_EXP_off',
#  'home_year_off',
#  'home_week_off',
#  'home_PFPerGame',
#  'home_YdsPerGame_off',
#  'home_TotYdsPlusTOPlyPerGame_off',
#  'home_TotYdsPlusTOTOPerGame_off',
#  'home_FLPerGame_off',
#  'home_1stDPerGame_off',
#  'home_PassingCmpPerGame_off',
#  'home_PassingAttPerGame_off',
#  'home_PassingYdsPerGame_off',
#  'home_PassingTDPerGame_off',
#  'home_PassingIntPerGame_off',
#  'home_Passing1stDPerGame_off',
#  'home_RushingAttPerGame_off',
#  'home_RushingYdsPerGame_off',
#  'home_RushingTDPerGame_off',
#  'home_Rushing1stDPerGame_off',
#  'home_PenaltiesPenPerGame_off',
#  'home_PenaltiesYdsPerGame_off',
#  'home_Penalties1stPyPerGame_off',
#  'home_Rk_def',
#  'home_G_def',
#  'home_PA',
#  'home_TotYdsPlusTOYPerP_def',
#  'home_PassingNYPerA_def',
#  'home_RushingYPerA_def',
#  'home_Sc%_def',
#  'home_TO%_def',
#  'home_EXP_def',
#  'home_YdsPerGame_def',
#  'home_TotYdsPlusTOPlyPerGame_def',
#  'home_TotYdsPlusTOTOPerGame_def',
#  'home_FLPerGame_def',
#  'home_1stDPerGame_def',
#  'home_PassingCmpPerGame_def',
#  'home_PassingAttPerGame_def',
#  'home_PassingYdsPerGame_def',
#  'home_PassingTDPerGame_def',
#  'home_PassingIntPerGame_def',
#  'home_Passing1stDPerGame_def',
#  'home_RushingAttPerGame_def',
#  'home_RushingYdsPerGame_def',
#  'home_RushingTDPerGame_def',
#  'home_Rushing1stDPerGame_def',
#  'home_PenaltiesPenPerGame_def',
#  'home_PenaltiesYdsPerGame_def',
#  'home_Penalties1stPyPerGame_def']

# %%
game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv").iloc[1].to_frame().T
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/def.csv
#           date      visiting_team visiting_score           home_team  \
# 1  Oct 2, 2022  Minnesota Vikings             28  New Orleans Saints
#
#   home_score status      visiting_team visiting_score visiting_Rk_off  \
# 1         25  Final  Minnesota Vikings             28              16
#
#   visiting_G_off  ... home_RushingYds_def home_RushingTD_def  \
# 1              3  ...                 418                  2
#
#   home_RushingYPerA_def home_Rushing1stD_def home_PenaltiesPen_def  \
# 1                   4.2                   21                    20
#
#   home_PenaltiesYds_def home_Penalties1stPy_def home_Sc%_def home_TO%_def  \
# 1                   196                       9         34.2          7.9
#
#   home_EXP_def
# 1        10.71
#
# [1 rows x 122 columns]

# %%
print(game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv").iloc[1].to_frame())
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/def.csv
#                                           1
# date                            Oct 2, 2022
# visiting_team             Minnesota Vikings
# visiting_score                           28
# home_team                New Orleans Saints
# home_score                               25
# ...                                     ...
# home_PenaltiesYds_def                   196
# home_Penalties1stPy_def                   9
# home_Sc%_def                           34.2
# home_TO%_def                            7.9
# home_EXP_def                          10.71
#
# [122 rows x 1 columns]

# %%
pd.set_option('display.max_rows', None)
print(game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv").iloc[1].to_frame())
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/def.csv
#                                                  1
# date                                   Oct 2, 2022
# visiting_team                    Minnesota Vikings
# visiting_score                                  28
# home_team                       New Orleans Saints
# home_score                                      25
# status                                       Final
# visiting_team                    Minnesota Vikings
# visiting_score                                  28
# visiting_Rk_off                                 16
# visiting_G_off                                   3
# visiting_PF                                     58
# visiting_Yds_off                              1032
# visiting_TotYdsPlusTOPly_off                   187
# visiting_TotYdsPlusTOYPerP_off                 5.5
# visiting_TotYdsPlusTOTO_off                      4
# visiting_FL_off                                  1
# visiting_1stD_off                               69
# visiting_PassingCmp_off                         74
# visiting_PassingAtt_off                        119
# visiting_PassingYds_off                        721
# visiting_PassingTD_off                           5
# visiting_PassingInt_off                          3
# visiting_PassingNYPerA_off                     5.9
# visiting_Passing1stD_off                        44
# visiting_RushingAtt_off                         64
# visiting_RushingYds_off                        311
# visiting_RushingTD_off                           2
# visiting_RushingYPerA_off                      4.9
# visiting_Rushing1stD_off                        19
# visiting_PenaltiesPen_off                       11
# visiting_PenaltiesYds_off                       60
# visiting_Penalties1stPy_off                      6
# visiting_Sc%_off                              30.3
# visiting_TO%_off                              12.1
# visiting_EXP_off                             13.71
# visiting_year_off                             2022
# visiting_week_off                                4
# visiting_Rk_def                                  9
# visiting_G_def                                   3
# visiting_PA                                     55
# visiting_Yds_def                              1240
# visiting_TotYdsPlusTOPly_def                   205
# visiting_TotYdsPlusTOYPerP_def                 6.0
# visiting_TotYdsPlusTOTO_def                      4
# visiting_FL_def                                  1
# visiting_1stD_def                               69
# visiting_PassingCmp_def                         77
# visiting_PassingAtt_def                        111
# visiting_PassingYds_def                        827
# visiting_PassingTD_def                           2
# visiting_PassingInt_def                          3
# visiting_PassingNYPerA_def                     7.0
# visiting_Passing1stD_def                        40
# visiting_RushingAtt_def                         87
# visiting_RushingYds_def                        413
# visiting_RushingTD_def                           5
# visiting_RushingYPerA_def                      4.7
# visiting_Rushing1stD_def                        24
# visiting_PenaltiesPen_def                       17
# visiting_PenaltiesYds_def                      129
# visiting_Penalties1stPy_def                      5
# visiting_Sc%_def                              27.3
# visiting_TO%_def                              12.1
# visiting_EXP_def                            -20.62
# home_team                       New Orleans Saints
# home_score                                      25
# home_Rk_off                                     23
# home_G_off                                       3
# home_PF                                         51
# home_Yds_off                                  1119
# home_TotYdsPlusTOPly_off                       187
# home_TotYdsPlusTOYPerP_off                     6.0
# home_TotYdsPlusTOTO_off                          9
# home_FL_off                                      4
# home_1stD_off                                   55
# home_PassingCmp_off                             73
# home_PassingAtt_off                            115
# home_PassingYds_off                            784
# home_PassingTD_off                               4
# home_PassingInt_off                              5
# home_PassingNYPerA_off                         6.2
# home_Passing1stD_off                            35
# home_RushingAtt_off                             61
# home_RushingYds_off                            335
# home_RushingTD_off                               2
# home_RushingYPerA_off                          5.5
# home_Rushing1stD_off                            15
# home_PenaltiesPen_off                           24
# home_PenaltiesYds_off                          217
# home_Penalties1stPy_off                          5
# home_Sc%_off                                  23.7
# home_TO%_off                                  23.7
# home_EXP_off                                -18.36
# home_year_off                                 2022
# home_week_off                                    4
# home_Rk_def                                     19
# home_G_def                                       3
# home_PA                                         68
# home_Yds_def                                   969
# home_TotYdsPlusTOPly_def                       195
# home_TotYdsPlusTOYPerP_def                     5.0
# home_TotYdsPlusTOTO_def                          3
# home_FL_def                                      3
# home_1stD_def                                   51
# home_PassingCmp_def                             50
# home_PassingAtt_def                             92
# home_PassingYds_def                            551
# home_PassingTD_def                               2
# home_PassingInt_def                              0
# home_PassingNYPerA_def                         5.7
# home_Passing1stD_def                            21
# home_RushingAtt_def                             99
# home_RushingYds_def                            418
# home_RushingTD_def                               2
# home_RushingYPerA_def                          4.2
# home_Rushing1stD_def                            21
# home_PenaltiesPen_def                           20
# home_PenaltiesYds_def                          196
# home_Penalties1stPy_def                          9
# home_Sc%_def                                  34.2
# home_TO%_def                                   7.9
# home_EXP_def                                 10.71
