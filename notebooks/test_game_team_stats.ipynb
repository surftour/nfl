# %%
import requests
import json
import pandas as pd
from datetime import datetime
import sys
print(sys.version)
# Out:
# 3.12.8 (main, Jul  3 2025, 14:08:45) [Clang 16.0.0 (clang-1600.0.26.3)]

# %%
sys.path.append('../')
import src.api.espn as espn
import src.data.reader_weekly_offdef as weekly_reader
import src.data.reader_weekly_results as weekly_results_reader

# %%
weekly_results_reader.read_weekly_game_results?
# Out:
# Signature: weekly_results_reader.read_weekly_game_results(file_path)
# Docstring:
# Read weekly game results from a TSV file and convert to DataFrame
#
# Args:
#     file_path: Path to the TSV file containing game results
#
# Returns:
#     DataFrame with columns: date, visiting_team, visiting_score, home_team, home_score, status
# File:      ~/nfl/src/data/weekly_results_reader.py
# Type:      function

# %%
weekly_results_reader.read_weekly_game_results("/Users/tj/nfl/data/2022/week4/results.tsv")
# Out:
#             date          visiting_team  visiting_score             home_team  \
# 0   Sep 29, 2022         Miami Dolphins              15    Cincinnati Bengals
# 1    Oct 2, 2022      Minnesota Vikings              28    New Orleans Saints
# 2    Oct 2, 2022       Cleveland Browns              20       Atlanta Falcons
# 3    Oct 2, 2022       Tennessee Titans              24    Indianapolis Colts
# 4    Oct 2, 2022  Washington Commanders              10        Dallas Cowboys
# 5    Oct 2, 2022       Seattle Seahawks              48         Detroit Lions
# 6    Oct 2, 2022   Los Angeles Chargers              34        Houston Texans
# 7    Oct 2, 2022          Chicago Bears              12       New York Giants
# 8    Oct 2, 2022   Jacksonville Jaguars              21   Philadelphia Eagles
# 9    Oct 2, 2022          New York Jets              24   Pittsburgh Steelers
# 10   Oct 2, 2022          Buffalo Bills              23      Baltimore Ravens
# ...

# %%
import src.analytics.game_team_stats as game_team_stats

# %%
game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv")
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/def.csv
#             date          visiting_team  visiting_score             home_team  \
# 0   Sep 29, 2022         Miami Dolphins              15    Cincinnati Bengals
# 1    Oct 2, 2022      Minnesota Vikings              28    New Orleans Saints
# 2    Oct 2, 2022       Cleveland Browns              20       Atlanta Falcons
# 3    Oct 2, 2022       Tennessee Titans              24    Indianapolis Colts
# 4    Oct 2, 2022  Washington Commanders              10        Dallas Cowboys
# 5    Oct 2, 2022       Seattle Seahawks              48         Detroit Lions
# 6    Oct 2, 2022   Los Angeles Chargers              34        Houston Texans
# 7    Oct 2, 2022          Chicago Bears              12       New York Giants
# 8    Oct 2, 2022   Jacksonville Jaguars              21   Philadelphia Eagles
# ...

# %%
print(game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv").dtypes)
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/def.csv
# date                        object
# visiting_team               object
# visiting_score               int64
# home_team                   object
# home_score                   int64
#                             ...
# home_PenaltiesYds_def        Int64
# home_Penalties1stPy_def      Int64
# home_Sc%_def               float64
# home_TO%_def               float64
# home_EXP_def               float64
# Length: 122, dtype: object

# %%
game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv").columns
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/def.csv
# Index(['date', 'visiting_team', 'visiting_score', 'home_team', 'home_score',
#        'status', 'visiting_team', 'visiting_score', 'visiting_Rk_off',
#        'visiting_G_off',
#        ...
#        'home_RushingYds_def', 'home_RushingTD_def', 'home_RushingYPerA_def',
#        'home_Rushing1stD_def', 'home_PenaltiesPen_def',
#        'home_PenaltiesYds_def', 'home_Penalties1stPy_def', 'home_Sc%_def',
#        'home_TO%_def', 'home_EXP_def'],
#       dtype='object', length=122)

# %%
game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv").columns.tolist()
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/def.csv
# ['date',
#  'visiting_team',
#  'visiting_score',
#  'home_team',
#  'home_score',
#  'status',
#  'visiting_team',
#  'visiting_score',
#  'visiting_Rk_off',
#  'visiting_G_off',
#  'visiting_PF',
#  'visiting_Yds_off',
#  'visiting_TotYdsPlusTOPly_off',
#  'visiting_TotYdsPlusTOYPerP_off',
#  'visiting_TotYdsPlusTOTO_off',
#  'visiting_FL_off',
#  'visiting_1stD_off',
#  'visiting_PassingCmp_off',
#  'visiting_PassingAtt_off',
#  'visiting_PassingYds_off',
#  'visiting_PassingTD_off',
#  'visiting_PassingInt_off',
#  'visiting_PassingNYPerA_off',
#  'visiting_Passing1stD_off',
#  'visiting_RushingAtt_off',
#  'visiting_RushingYds_off',
#  'visiting_RushingTD_off',
#  'visiting_RushingYPerA_off',
#  'visiting_Rushing1stD_off',
#  'visiting_PenaltiesPen_off',
#  'visiting_PenaltiesYds_off',
#  'visiting_Penalties1stPy_off',
# ...

# %%
game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv").iloc[1].to_frame().T
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/def.csv
#           date      visiting_team visiting_score           home_team  \
# 1  Oct 2, 2022  Minnesota Vikings             28  New Orleans Saints
#
#   home_score status      visiting_team visiting_score visiting_Rk_off  \
# 1         25  Final  Minnesota Vikings             28              16
#
#   visiting_G_off  ... home_RushingYds_def home_RushingTD_def  \
# 1              3  ...                 418                  2
#
#   home_RushingYPerA_def home_Rushing1stD_def home_PenaltiesPen_def  \
# 1                   4.2                   21                    20
#
#   home_PenaltiesYds_def home_Penalties1stPy_def home_Sc%_def home_TO%_def  \
# 1                   196                       9         34.2          7.9
#
#   home_EXP_def
# 1        10.71
#
# [1 rows x 122 columns]

# %%
print(game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv").iloc[1].to_frame())
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/def.csv
#                                           1
# date                            Oct 2, 2022
# visiting_team             Minnesota Vikings
# visiting_score                           28
# home_team                New Orleans Saints
# home_score                               25
# ...                                     ...
# home_PenaltiesYds_def                   196
# home_Penalties1stPy_def                   9
# home_Sc%_def                           34.2
# home_TO%_def                            7.9
# home_EXP_def                          10.71
#
# [122 rows x 1 columns]

# %%
pd.set_option('display.max_rows', None)
print(game_team_stats.combine_game_results_with_team_stats(2022,4,"/Users/tj/nfl/data/2022/week4/results.tsv").iloc[1].to_frame())
# Out:
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/off.csv
# Processing CSV file: /Users/tj/nfl/notebooks/../data/2022/week4/def.csv
#                                                  1
# date                                   Oct 2, 2022
# visiting_team                    Minnesota Vikings
# visiting_score                                  28
# home_team                       New Orleans Saints
# home_score                                      25
# status                                       Final
# visiting_team                    Minnesota Vikings
# visiting_score                                  28
# visiting_Rk_off                                 16
# visiting_G_off                                   3
# visiting_PF                                     58
# visiting_Yds_off                              1032
# visiting_TotYdsPlusTOPly_off                   187
# visiting_TotYdsPlusTOYPerP_off                 5.5
# visiting_TotYdsPlusTOTO_off                      4
# ...
